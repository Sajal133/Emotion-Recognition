# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from tensorflow.keras.utils import img_to_array,load_img
from keras.preprocessing.image import ImageDataGenerator 
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "dataset/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 57418 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "dataset/test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11256\564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 18.7526 - accuracy: 0.1813
# Epoch 1: val_accuracy improved from -inf to 0.34375, saving model to best_model.h5
# 10/10 [==============================] - 22s 2s/step - loss: 18.7526 - accuracy: 0.1813 - val_loss: 9.2116 - val_accuracy: 0.3438
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 10.8773 - accuracy: 0.3125
# Epoch 2: val_accuracy did not improve from 0.34375
# 10/10 [==============================] - 19s 2s/step - loss: 10.8773 - accuracy: 0.3125 - val_loss: 8.6090 - val_accuracy: 0.3438
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 7.3643 - accuracy: 0.3469
# Epoch 3: val_accuracy improved from 0.34375 to 0.38281, saving model to best_model.h5
# 10/10 [==============================] - 19s 2s/step - loss: 7.3643 - accuracy: 0.3469 - val_loss: 5.6454 - val_accuracy: 0.3828
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6838 - accuracy: 0.3500
# Epoch 4: val_accuracy improved from 0.38281 to 0.41797, saving model to best_model.h5
# 10/10 [==============================] - 19s 2s/step - loss: 5.6838 - accuracy: 0.3500 - val_loss: 5.2831 - val_accuracy: 0.4180
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 4.5279 - accuracy: 0.4250
# Epoch 5: val_accuracy did not improve from 0.41797
# 10/10 [==============================] - 18s 2s/step - loss: 4.5279 - accuracy: 0.4250 - val_loss: 5.8764 - val_accuracy: 0.3477
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 4.5001 - accuracy: 0.4344
# Epoch 6: val_accuracy did not improve from 0.41797
# 10/10 [==============================] - 18s 2s/step - loss: 4.5001 - accuracy: 0.4344 - val_loss: 5.2177 - val_accuracy: 0.4023
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 4.7409 - accuracy: 0.4219
# Epoch 7: val_accuracy did not improve from 0.41797
# 10/10 [==============================] - 18s 2s/step - loss: 4.7409 - accuracy: 0.4219 - val_loss: 5.3350 - val_accuracy: 0.3750
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 3.9611 - accuracy: 0.4875
# Epoch 8: val_accuracy improved from 0.41797 to 0.42969, saving model to best_model.h5
# 10/10 [==============================] - 19s 2s/step - loss: 3.9611 - accuracy: 0.4875 - val_loss: 5.6665 - val_accuracy: 0.4297
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7566 - accuracy: 0.3844
# Epoch 9: val_accuracy improved from 0.42969 to 0.43359, saving model to best_model.h5
# 10/10 [==============================] - 18s 2s/step - loss: 5.7566 - accuracy: 0.3844 - val_loss: 4.5161 - val_accuracy: 0.4336
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 5.2507 - accuracy: 0.4437
# Epoch 10: val_accuracy improved from 0.43359 to 0.46094, saving model to best_model.h5
# 10/10 [==============================] - 19s 2s/step - loss: 5.2507 - accuracy: 0.4437 - val_loss: 4.1598 - val_accuracy: 0.4609
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 5.4303 - accuracy: 0.4187
# Epoch 11: val_accuracy did not improve from 0.46094
# 10/10 [==============================] - 18s 2s/step - loss: 5.4303 - accuracy: 0.4187 - val_loss: 4.7113 - val_accuracy: 0.4492
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 4.9649 - accuracy: 0.4125
# Epoch 12: val_accuracy did not improve from 0.46094
# 10/10 [==============================] - 19s 2s/step - loss: 4.9649 - accuracy: 0.4125 - val_loss: 5.5931 - val_accuracy: 0.4336
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 6.8847 - accuracy: 0.4027
# Epoch 13: val_accuracy did not improve from 0.46094
# 10/10 [==============================] - 22s 2s/step - loss: 6.8847 - accuracy: 0.4027 - val_loss: 6.3309 - val_accuracy: 0.4336
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 6.1947 - accuracy: 0.4250
# Epoch 14: val_accuracy did not improve from 0.46094
# 10/10 [==============================] - 19s 2s/step - loss: 6.1947 - accuracy: 0.4250 - val_loss: 8.3885 - val_accuracy: 0.3906
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 7.8559 - accuracy: 0.4094
# Epoch 15: val_accuracy did not improve from 0.46094
# 10/10 [==============================] - 18s 2s/step - loss: 7.8559 - accuracy: 0.4094 - val_loss: 6.5752 - val_accuracy: 0.3984
# Epoch 15: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "c.webp"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 66ms/step
#  the image is of happy
